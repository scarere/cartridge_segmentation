# %%
# Just importing the main function so that results can be viewed without having to run the code
from main import main

mm9 = 'Cwrbf0001-9mm.png' # 9mm, negligible (very small) firing pin drag
mm4010 = 'Lightstone-40-10mm.png' # 40/10mm, large firing pin drag present

# %%
main(mm9) # perform the segmentation algorithm on the 9mm image

# %%
main(mm4010) # perform the segmentation algorithm on the 40-10mm image
